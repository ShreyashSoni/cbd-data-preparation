# %%
cd /app
# Out:
# /app
# /home/shre/venv/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd

# %%
df = pd.read_csv("./data/raw/twitter/cyberbullying_tweets.csv")

# %%
print(f"{df.shape=}")
# Out:
# df.shape=(47692, 2)

# %%
(len(df) - (len(df) * 0.2)) * 0.25
# Out:
# 9538.4

# %%
df.sample(n=50)
# Out:
#                                               tweet_text   cyberbullying_type
# 20028  #Hinduphobia_in_Arab Arab world : &gt;No Democ...             religion
# 3766   NPR asked to speak to me about the wadhwa thin...    not_cyberbullying
# 45693  exactly , yall r dumb if u think there isn’t S...            ethnicity
# 1258   @diegodondiego a @lpcarvalho disse que já poss...    not_cyberbullying
# 39771  FUCK YOU BITCH!! he got 4 more yrs, get used t...            ethnicity
# 34108  I love seeing the girls in high school that we...                  age
# 21550  Terrorist groups have no legitimacy or authori...             religion
# 44502   Now beat the fuck out of each other dumb niggers            ethnicity
# 15596  GYUK | Anti-feminist YouTuber doubles down on ...               gender
# 28686  Pre-GDC SJW chillfest evening of March 1st. Em...  other_cyberbullying
# 35512  I didn’t get bullied in high school but i reme...                  age
# 39978  “@LICKmySTACKS: You mad bitch !? “@tayyoung_: ...            ethnicity
# 15102  Als say he aint a virgin....my ass.  -___-...d...               gender
# 34864  Now what about the girl back in high school wh...                  age
# 9328   @mikeyfenn You appear to have common sense.  S...               gender
# 28775  http://t.co/Wc7swzOMdi - all of these experts,...  other_cyberbullying
# 32142  Looking back at Facebook messages between me a...                  age
# 1686   #RobandDave &amp; #AshandCamilla are the stron...    not_cyberbullying
# 29935  @ANN_Lynzee heh, thanks. i try. it just gets t...  other_cyberbullying
# 25784  Don't try to explain the internet to women. ht...  other_cyberbullying
# 3763   Porque o aplicativo do tumblr não esta disponi...    not_cyberbullying
# 12052  Here's my issue with people like the gay TV pr...               gender
# 45228  This is what happens when ur a dumb nigger«@iA...            ethnicity
# 3694   @torionsellers TORION..... Would you ever go t...    not_cyberbullying
# 39287  Yea I'm totally boring when you've been replyi...                  age
# 28836  @finicalgal And dazzling white lights in his g...  other_cyberbullying
# 37789  Oh, look, we're back in grade school with the ...                  age
# 19560  Pastor Ralph Reed: Evangelicals have "moral ob...             religion
# 3398   It's a doggy dogg world #bully #stafford #teko...    not_cyberbullying
# 10438  I'm sorry, can't agree. We're all appalled and...               gender
# 29477  @DiscordianKitty I never use caps lock. I alwa...  other_cyberbullying
# 24250  Bloody splicers sealed Johnny in before they.....  other_cyberbullying
# 8220   Yep. U got that. Mr tuff guy. MAGA ðð¤£ ju...               gender
# 21063  @KellyTurner99 @buellerishere Yes, those milli...             religion
# 45706  RT @Spazzin_Steve: @Jovzilla @EvelynLozada YOU...            ethnicity
# 21758  You look at Muslim's everywhere in the world t...             religion
# 23513  It’s so disgraceful that you even call yoursel...             religion
# 36908  The same girls that are posting ‘in a world wh...                  age
# 12910  The sexist litmus test is if you call out a lv...               gender
# 8856   Rape cases with men as the victims should be t...               gender
# 7814   De javu! I tweeted at the early stage of #MKR ...    not_cyberbullying
# 42016  @LadyxGodiva You rock! Fuck that ugly nigger b...            ethnicity
# 28564                                @girlziplocked jfc.  other_cyberbullying
# 33234  kinda look like my middle school bully with my...                  age
# 5575   @MathewSwag Hey bruhh did you see my free anti...    not_cyberbullying
# 37021  When you were in Middle school or high school....                  age
# 16399  So am I worthy of a good Christian woman? Ridi...             religion
# 33780  was looking for a coworker earlier and almost ...                  age
# 14283  y’all gotta cut it tf out. you been in females...               gender
# 38017  The same way the cut ties with the WHO, bully ...                  age

# %%
df["cyberbullying_type"].unique()
# Out:
# array(['not_cyberbullying', 'gender', 'religion', 'other_cyberbullying',
#        'age', 'ethnicity'], dtype=object)
